# %%
import os
import cv2
import numpy as np
import pathlib as pl
import matplotlib.pyplot as plt
print(os.getcwd())
# Out:
# D:\Document\4ES工学実験\演算増幅回路の制作と特性測定

# %%
print(os.listdir(os.getcwd()))
path = 'images'
print(path)
files = os.listdir(path)
print(files)
# Out:
# ['.ipynb_checkpoints', 'data.xlsx', 'experiment', 'images', 'Result', '~$data.xlsx', 'グレースケール化.ipynb', '演算増幅回路の制作と特性測定.aux', '演算増幅回路の制作と特性測定.fdb_latexmk', '演算増幅回路の制作と特性測定.fls', '演算増幅回路の制作と特性測定.log', '演算増幅回路の制作と特性測定.pdf', '演算増幅回路の制作と特性測定.synctex.gz', '演算増幅回路の制作と特性測定.tex']
# images
# ['100Hz_47000pF-1.bmp', '100Hz_47000pF.bmp', '100Hz_4900pF.bmp', '10kHz_47000pF-1.bmp', '10kHz_47000pF.bmp', '10kHz_4900pF.bmp', '1kHz_47000pF-1.bmp', '1kHz_47000pF.bmp', '1kHz_4900pF.bmp', 'Hannten(input_10mV_output_95mV).bmp', 'Hannten(input_1V_output_9.12V).bmp', 'Hannten(input_8.12V_output_12.2V).bmp', 'Hihannten(input_1000mV_output_9600mV).bmp', 'Hihannten(input_100mV_output_1080mV).bmp', 'Hihannten(input_3000mV_output_11900mV).bmp']

# %%
pl.Path('Result\\Reverse').mkdir(exist_ok=True)
for i, name in enumerate(files):
    print(str(i+1) + "ファイル目 : " + path + "\\" + name)
    img = cv2.imread(path + "\\" + name)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    print(img.shape)

    for x in range(img.shape[0]):
        for y in range(img.shape[1]):
            for z in range(img.shape[2]):
                img[x][y][z] = 255 - img[x][y][z]

    plt.figure(dpi=1000)
    plt.tick_params(labelbottom=False,
                    labelleft=False,
                    labelright=False,
                    labeltop=False,
                    bottom=False,
                    left=False,
                    right=False,
                    top=False)
    plt.gca().spines['right'].set_visible(False)
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['left'].set_visible(False)
    plt.gca().spines['bottom'].set_visible(False)
    plt.imshow(img)
    plt.grid(False)
    plt.savefig("Result\\Reverse\\reverse-" + name.split(".")[0] + ".png")
# Out:
# 1ファイル目 : images\100Hz_47000pF-1.bmp
# (524, 734, 3)
# 2ファイル目 : images\100Hz_47000pF.bmp
# (524, 734, 3)
# 3ファイル目 : images\100Hz_4900pF.bmp
# (524, 734, 3)
# 4ファイル目 : images\10kHz_47000pF-1.bmp
# (524, 734, 3)
# 5ファイル目 : images\10kHz_47000pF.bmp
# (524, 734, 3)
# 6ファイル目 : images\10kHz_4900pF.bmp
# (524, 734, 3)
# 7ファイル目 : images\1kHz_47000pF-1.bmp
# (524, 734, 3)
# 8ファイル目 : images\1kHz_47000pF.bmp
# (524, 734, 3)
# 9ファイル目 : images\1kHz_4900pF.bmp
# (524, 734, 3)
# 10ファイル目 : images\Hannten(input_10mV_output_95mV).bmp
# (524, 734, 3)
# 11ファイル目 : images\Hannten(input_1V_output_9.12V).bmp
# (751, 1052, 3)
# 12ファイル目 : images\Hannten(input_8.12V_output_12.2V).bmp
# (751, 1052, 3)
# 13ファイル目 : images\Hihannten(input_1000mV_output_9600mV).bmp
# (751, 1052, 3)
# 14ファイル目 : images\Hihannten(input_100mV_output_1080mV).bmp
# (751, 1052, 3)
# 15ファイル目 : images\Hihannten(input_3000mV_output_11900mV).bmp
# (751, 1052, 3)
# ---------------------------------------------------------------------------
# ...

# %%
pl.Path('Result\\Monotone').mkdir(exist_ok=True)
for i, name in enumerate(files):
    print(str(i+1) + "ファイル目 : " + path + "\\" + name)
    img = cv2.imread(path + "\\" + name)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    print(img.shape)

    for x in range(img.shape[0]):
        for y in range(img.shape[1]):
            temp = 0.3 * img[x][y][0] + 0.6 * img[x][y][1] + 0.1 * img[x][y][2]
            for z in range(img.shape[2]):
                img[x][y][z] = 255 - temp
                
    plt.figure(dpi=1000)
    plt.tick_params(labelbottom=False,
                    labelleft=False,
                    labelright=False,
                    labeltop=False,
                    bottom=False,
                    left=False,
                    right=False,
                    top=False)
    plt.gca().spines['right'].set_visible(False)
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['left'].set_visible(False)
    plt.gca().spines['bottom'].set_visible(False)
    plt.imshow(img)
    plt.grid(False)
    plt.savefig("Result\\Monotone\\mono-" + name.split(".")[0] + ".png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-b9a959b1b8dd> in <module>
# ----> 1 pl.Path('Result\\Monotone').mkdir(exist_ok=True)
#       2 for i, name in enumerate(files):
#       3     print(str(i+1) + "ファイル目 : " + path + "\\" + name)
#       4     img = cv2.imread(path + "\\" + name)
#       5     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#
# D:\software\anaconda\lib\pathlib.py in mkdir(self, mode, parents, exist_ok)
#    1249             self._raise_closed()
#    1250         try:
# -> 1251             self._accessor.mkdir(self, mode)
#    1252         except FileNotFoundError:
#    1253             if not parents or self.parent == self:
#
# FileNotFoundError: [WinError 3] 指定されたパスが見つかりません。: 'Result\\Monotone'
