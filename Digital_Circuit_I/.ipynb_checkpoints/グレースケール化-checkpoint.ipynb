# %%
import os
import cv2
import numpy as np
import pathlib as pl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print(os.listdir(os.getcwd()))
path = 'images'
print(path)
print(os.listdir(path))
# Out:
# ['.ipynb', '.ipynb_checkpoints', 'images', 'sp0.png', 'untitled-1.aux', 'untitled-1.log', 'untitled-1.pdf', 'untitled-1.synctex.gz', 'untitled-1.tex', 'Untitled.ipynb', 'グレースケール化.ipynb', 'ディジタル回路1.ipynb', 'ディジタル回路1.xlsx', 'ディジタル回路I.aux', 'ディジタル回路I.fdb_latexmk', 'ディジタル回路I.fls', 'ディジタル回路I.log', 'ディジタル回路I.pdf', 'ディジタル回路I.synctex.gz', 'ディジタル回路I.tex']
# images
# ['223KC-Va.bmp', '223KC-Vb.bmp', '223KC-Vd.bmp', '223KC-Vout-Va.bmp', '223KC-Vout-Vb.bmp', '223KC-Vout-Vd-ex.bmp', '223KC-Vout-Vd.bmp', '223KC-Vout.bmp', '224J-Va.bmp', '224J-Vb.bmp', '224J-Vd.bmp', '224J-Vout-Va.bmp', '224J-Vout-Vb.bmp', '224J-Vout-Vd-ex.bmp', '224J-Vout-Vd.bmp', '224J-Vout.bmp', '5V.bmp', 'GND.bmp', 'R105M-Va.bmp', 'R105M-Vb.bmp', 'R105M-Vd.bmp', 'R105M-Vout-Va.bmp', 'R105M-Vout-Vb.bmp', 'R105M-Vout-Vd-ex.bmp', 'R105M-Vout-Vd.bmp', 'R105M-Vout.bmp']

# %%
INDEX = 2

print(path + "\\" + files[INDEX])
img = cv2.imread(path + "\\" + files[INDEX])
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
print(img.shape)
plt.imshow(img)
for x in range(img.shape[0]):
    for y in range(img.shape[1]):
        for z in range(img.shape[2]):
            img[x][y][z] = 255 - img[x][y][z]

plt.figure(dpi=1000)
plt.tick_params(labelbottom=False,
                labelleft=False,
                labelright=False,
                labeltop=False,
                bottom=False,
                left=False,
                right=False,
                top=False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.imshow(img)
plt.grid(False)
plt.savefig("Result\\reverse-" + files[INDEX] + ".png")
# Out:
# images\223KC-Vd.bmp
# (524, 734, 3)

# %%
pl.Path('Result').mkdir(exist_ok=True)
for i, name in enumerate(files):
    print(str(i+1) + "ファイル目 : " + path + "\\" + name)
    img = cv2.imread(path + "\\" + name)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    print(img.shape)

    for x in range(img.shape[0]):
        for y in range(img.shape[1]):
            for z in range(img.shape[2]):
                img[x][y][z] = 255 - img[x][y][z]

    plt.figure(dpi=1000)
    plt.tick_params(labelbottom=False,
                    labelleft=False,
                    labelright=False,
                    labeltop=False,
                    bottom=False,
                    left=False,
                    right=False,
                    top=False)
    plt.gca().spines['right'].set_visible(False)
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['left'].set_visible(False)
    plt.gca().spines['bottom'].set_visible(False)
    # plt.imshow(img)
    # plt.grid(False)
    plt.savefig("Result\\reverse-" + name + ".png")
# Out:
# 1ファイル目 : images\223KC-Va.bmp
# (524, 734, 3)
# 2ファイル目 : images\223KC-Vb.bmp
# (524, 734, 3)
# 3ファイル目 : images\223KC-Vd.bmp
# (524, 734, 3)
